# %%
import pandas as pd

# %%
dados = pd.read_csv('../dados_brutos/caso_full.csv.gz', parse_dates=['date', 'last_available_date'])

# %%
dados.head()
# Out:
#          city  city_ibge_code       date  epidemiological_week  \
# 0  Rio Branco       1200401.0 2020-03-17                202012
# 1         NaN            12.0 2020-03-17                202012
# 2  Rio Branco       1200401.0 2020-03-18                202012
# 3         NaN            12.0 2020-03-18                202012
# 4  Rio Branco       1200401.0 2020-03-19                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 1              894470.0                   881935.0    False        False
# 2              413418.0                   407319.0    False        False
# 3              894470.0                   881935.0    False        False
# 4              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
len(dados.columns)
# Out:
# 18

# %%
dados = dados.rename(columns={'new_confirmed':'casos_novos', 'new_deaths':'obitos_novos'})
dados.head()
# Out:
#          city  city_ibge_code       date  epidemiological_week  \
# 0  Rio Branco       1200401.0 2020-03-17                202012
# 1         NaN            12.0 2020-03-17                202012
# 2  Rio Branco       1200401.0 2020-03-18                202012
# 3         NaN            12.0 2020-03-18                202012
# 4  Rio Branco       1200401.0 2020-03-19                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 1              894470.0                   881935.0    False        False
# 2              413418.0                   407319.0    False        False
# 3              894470.0                   881935.0    False        False
# 4              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
dados_br = dados[dados['place_type'] == 'state'].groupby(['date', 'epidemiological_week']).agg({'casos_novos':'sum', 'obitos_novos':'sum'}).reset_index()
dados_br.head()
# Out:
#         date  epidemiological_week  casos_novos  obitos_novos
# 0 2020-02-25                202009            1             0
# 1 2020-02-26                202009            0             0
# 2 2020-02-27                202009            0             0
# 3 2020-02-28                202009            1             0
# 4 2020-02-29                202009            0             0

# %%
dados_br['MM7_casos'] = dados_br['casos_novos'].rolling(7, center=False).mean()
dados_br['MM7_obitos'] = dados_br['obitos_novos'].rolling(7, center=False).mean()
dados_br['mes/ano'] = dados_br['date'].dt.strftime('%m-%Y')
dados_br.head()
# Out:
#         date  epidemiological_week  casos_novos  obitos_novos  MM7_casos  \
# 0 2020-02-25                202009            1             0        NaN
# 1 2020-02-26                202009            0             0        NaN
# 2 2020-02-27                202009            0             0        NaN
# 3 2020-02-28                202009            1             0        NaN
# 4 2020-02-29                202009            0             0        NaN
#
#    MM7_obitos  mes/ano
# 0         NaN  02-2020
# 1         NaN  02-2020
# 2         NaN  02-2020
# 3         NaN  02-2020
# 4         NaN  02-2020

# %%
let_mes = dados_br.groupby('mes/ano').agg({'casos_novos':'sum', 'obitos_novos':'sum'})
let_mes['letalidade_mes'] = let_mes['obitos_novos'] / let_mes['casos_novos']
let_mes = let_mes.reset_index()

# %%
dados_br = dados_br.merge(let_mes[['mes','letalidade_mes']], on='mes')
dados_br.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-04a1b8cb3699> in <module>
# ----> 1 dados_br = dados_br.merge(let_mes[['mes','letalidade_mes']], on='mes')
#       2 dados_br.head()
#
# ~\anaconda3_02\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3_02\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
# ...

# %%
dados[''])
# Out:
# array(['Rio Branco', nan, 'Acrelândia', ..., 'Talismã', 'Tupirama',
#        'Tupiratins'], dtype=object)

# %%
dados_rj = dados[(dados['city'] == 'Rio de Janeiro')]
dados_rj = dados_rj.groupby('date').agg({'casos_novos':'sum', 'obitos_novos':'sum'}).reset_index()
dados_rj.head()
# Out:
#         date  casos_novos  obitos_novos
# 0 2020-03-06            1             0
# 1 2020-03-07            0             0
# 2 2020-03-08            1             0
# 3 2020-03-09            0             0
# 4 2020-03-10            0             0

# %%
dados_rj['MM7_casos'] = dados_rj['casos_novos'].rolling(7, center=False).mean()
dados_rj['MM7_obitos'] = dados_rj['obitos_novos'].rolling(7, center=False).mean()
dados_rj['mes'] = dados_rj['date'].dt.strftime('%m-%Y')
dados_rj.head()
# Out:
#         date  casos_novos  obitos_novos  MM7_casos  MM7_obitos      mes
# 0 2020-03-06            1             0        NaN         NaN  03-2020
# 1 2020-03-07            0             0        NaN         NaN  03-2020
# 2 2020-03-08            1             0        NaN         NaN  03-2020
# 3 2020-03-09            0             0        NaN         NaN  03-2020
# 4 2020-03-10            0             0        NaN         NaN  03-2020

# %%
let_mes_rj = dados_rj.groupby('mes').agg({'casos_novos':'sum', 'obitos_novos':'sum'})
let_mes_rj['letalidade_mes'] = let_mes_rj['obitos_novos'] / let_mes_rj['casos_novos']
let_mes_rj = let_mes_rj.reset_index()

# %%
dados_rj = dados_rj.merge(let_mes_rj[['mes','letalidade_mes']], on='mes')
dados_rj.head()
# Out:
#         date  casos_novos  obitos_novos  MM7_casos  MM7_obitos      mes  \
# 0 2020-03-06            1             0        NaN         NaN  03-2020
# 1 2020-03-07            0             0        NaN         NaN  03-2020
# 2 2020-03-08            1             0        NaN         NaN  03-2020
# 3 2020-03-09            0             0        NaN         NaN  03-2020
# 4 2020-03-10            0             0        NaN         NaN  03-2020
#
#    letalidade_mes
# 0        0.030717
# 1        0.030717
# 2        0.030717
# 3        0.030717
# 4        0.030717

# %%
dados_br.set_index(dados_br.columns[0]).to_csv('../dados_limpos/dados_br')

# %%
dados_rj.set_index(dados_rj.columns[0]).to_csv('../dados_limpos/dados_rj')
